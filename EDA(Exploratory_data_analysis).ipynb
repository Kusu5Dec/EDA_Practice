# %%
# EDA: Exploratory data analysis
# data ingestion
# EDA(data analysis)
# Data prep/data preorocessing/feature enginerring
# modelling
#profile of data
#statistical based analysis
#graphs based analysis

# %%
# automated EDA: pandas profiling,D-tale,dabl,Sweetviz,datatile,QuickDA

# %%
import pandas as pd

# %%
df=pd.read_csv("googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.sample()
# Out:
#                  App Category  Rating Reviews  Size  Installs  Type Price  \
# 2167  Chess PRO Free   FAMILY     3.8    1123  5.7M  100,000+  Free     0
#
#      Content Rating             Genres       Last Updated Current Ver  \
# 2167       Everyone  Board;Brain Games  September 8, 2016         4.2
#
#      Android Ver
# 2167  2.3 and up

# %%
df.sample(5)
# Out:
#                                  App            Category  Rating Reviews  \
# 1572                 ZenUI Safeguard           LIFESTYLE     4.5     100
# 1365          Map My Hike GPS Hiking  HEALTH_AND_FITNESS     4.4   12858
# 9037                        DX Alert               TOOLS     4.1      27
# 9002                     DW Security            BUSINESS     5.0       6
# 5475  500 AP World History Questions              FAMILY     4.7       7
#
#       Size    Installs  Type  Price Content Rating            Genres  \
# 1572  7.1M  1,000,000+  Free      0       Everyone         Lifestyle
# 1365   55M    500,000+  Free      0       Everyone  Health & Fitness
# 9037  2.5M      1,000+  Free      0       Everyone             Tools
# 9002   15M        100+  Free      0       Everyone          Business
# 5475  1.2M        100+  Paid  $9.99       Everyone         Education
#
#           Last Updated      Current Ver  Android Ver
# 1572       May 9, 2018  1.0.0.21_180410  7.0 - 7.1.1
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#insights:outlier,wrong value
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# to check duplicate value

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10358, dtype: float64

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df['Rating'].dtype
# Out:
# dtype('float64')

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df['Reviews'].unique()[:1000]
# Out:
# array(['159', '967', '87510', '215644', '167', '178', '36815', '13791',
#        '121', '13880', '8788', '44829', '4326', '1518', '55', '3632',
#        '27', '194216', '224399', '450', '654', '7699', '61', '118', '192',
#        '20260', '203', '136', '223', '1120', '227', '5035', '1015', '353',
#        '564', '8145', '36639', '158', '591', '117', '176', '295221',
#        '2206', '26', '174531', '1070', '85', '845', '367', '1598', '284',
#        '17057', '129', '542', '10479', '805', '1403', '3971', '534',
#        '7774', '38846', '2431', '6090', '295', '190', '40211', '356',
#        '52530', '116986', '1379', '271920', '736', '7021', '197', '737',
#        '3574', '994', '197136', '142', '15168', '2155', '138', '5414',
#        '21777', '348', '250', '13372', '7880', '3617', '4806', '65786',
#        '31433', '5097', '1754', '2680', '1288', '18900', '49790', '1150',
#        '1739', '32090', '2225', '4369', '8572', '964', '42050', '104',
# ...

# %%
df.Reviews.str

# %%
df.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: object

# %%
df.Reviews.str

# %%
df.Reviews.str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10358, dtype: bool

# %%
df[df.Reviews.str.isnumeric()]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df[~df["Reviews"].apply(lambda x:x.isnumeric())]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
type(df.Reviews)
# Out:
# pandas.core.series.Series

# %%
type(df.Reviews.str)
# Out:
# pandas.core.strings.accessor.StringMethods

# %%
df.Reviews.str

# %%
df_copy=df.copy()

# %%
df_copy.reset_index(drop=True)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy[~df["Reviews"].apply(lambda x:x.isnumeric())]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy.drop(df_copy.index[10354],inplace=True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Reviews'].dtypes
# Out:
# dtype('O')

# %%
import seaborn as sns

# %%
df_copy['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10835         0
# 10836        38
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10357, dtype: object

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10835                  9.6M
# 10836                   53M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10357, dtype: object

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# replace

# %%
df_copy['Size']=df_copy['Size'].str.replace("M","000")

# %%
df_copy['Size']
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10835                9.6000
# 10836                 53000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10357, dtype: object

# %%
df_copy['Size'] = df_copy['Size'].str.replace("K","")

# %%
import numpy as np

# %%
df_copy['Size'] = df_copy['Size'].str.replace("Varies with devices",str(np.nan))

# %%
df_copy['Size']
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10835                9.6000
# 10836                 53000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10357, dtype: object

# %%
df_copy['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10835            10+
# 10836         5,000+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10357, dtype: object

# %%
df_copy['Installs'].str.replace("+" ,"").str.replace(",","")
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10835          10
# 10836        5000
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10357, dtype: object

# %%
df_copy['Installs']=df_copy['Installs'].str.replace("+" ,"").str.replace(",","")

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy['Price']=df_copy['Price'].str.replace("$","")

# %%
df_copy["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        'Everyone', '1.20', '1.04'], dtype=object)

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
[feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
categorical_features=[feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
numerical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O']

# %%
numerical_features
# Out:
# ['Rating']

# %%
df_copy['Type'].value_counts(normalize=True)
# Out:
# Type
# Free    0.926033
# Paid    0.073870
# 0       0.000097
# Name: proportion, dtype: float64

# %%
import seaborn as sns

# %%
sns.countplot(x=df_copy['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df_copy['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10835      Everyone
# 10836      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10357, dtype: object

# %%
sns.countplot(x=df_copy['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.displot(df_copy['Price'])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(df_copy['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.kdeplot(df_copy['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(df_copy['Price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[270], line 1
# ----> 1 sns.kdeplot(df_copy['Price'])
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\distributions.py:1695, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1692 if ax is None:
#    1693     ax = plt.gca()
# -> 1695 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1697 method = ax.fill_between if fill else ax.plot
#    1698 color = _default_color(method, hue, color, kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1211, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
# ...

# %%
sns.boxplot(df_copy['Rating'])
# Out:
# <Axes: >

# %%
df_copy['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10835               BUSINESS
# 10836                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10357, dtype: object

# %%
df_copy['Category'].value_counts()
# Out:
# Category
# FAMILY                 1942
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],autopct='%1.1f%%',figsize=(12,12))
# Out:
# <Axes: ylabel='count'>

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],figsize=(12,12))
# Out:
# <Axes: ylabel='count'>

# %%
# what is top 10 category of app?

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy['Category'].value_counts()[:10]
# Out:
# Category
# FAMILY             1942
# GAME               1121
# TOOLS               843
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     388
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %%
# which category has the the highest installation?

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.groupby(['Category'])['Installs'].sum()
# Out:
# Category
# 1.9                                                                 Free
# ART_AND_DESIGN         1000050000050000005000000010000050000500001000...
# AUTO_AND_VEHICLES      1000001000000100000100000010000010000010000050...
# BEAUTY                 5000001000000100000500000100000050000010000010...
# BOOKS_AND_REFERENCE    1000000005000010000010000000100000000100000001...
# BUSINESS               1000000050000000100000005000000100000050000000...
# COMICS                 1000000050000010000005000005000050000500001000...
# COMMUNICATION          1000000000100000000010000000100000000010000000...
# DATING                 1000010005010010010010000000100000001000000010...
# EDUCATION              1000000001000000010000050000001000000010000050...
# ENTERTAINMENT          1000000001000000100000010000000500000001000000...
# EVENTS                 1000005000000500000500005000000100000010000100...
# FAMILY                 5000000010000000100000000100000050000005000000...
# ...

# %%
df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# 1.9                                                                 Free
# LIBRARIES_AND_DEMO     5000010000100000100010000010000100000500000050...
# BEAUTY                 5000001000000100000500000100000050000010000010...
# LIFESTYLE              5000000100000001000001000000050000001000000500...
# WEATHER                5000000010000005000000010000100000001000000100...
# PERSONALIZATION        5000000010000001000000005000000100000500000050...
# FAMILY                 5000000010000000100000000100000050000005000000...
# PRODUCTIVITY           5000000001000000010000000010000000100000000010...
# ART_AND_DESIGN         1000050000050000005000000010000050000500001000...
# PARENTING              1000050000001000010000001000010000100000100005...
# DATING                 1000010005010010010010000000100000001000000010...
# EVENTS                 1000005000000500000500005000000100000010000100...
# MEDICAL                1000001000010000100001000010000500050001000005...
# ...

# %%
df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()
# Out:
#                Category                                           Installs
# 0                   1.9                                               Free
# 1    LIBRARIES_AND_DEMO  5000010000100000100010000010000100000500000050...
# 2                BEAUTY  5000001000000100000500000100000050000010000010...
# 3             LIFESTYLE  5000000100000001000001000000050000001000000500...
# 4               WEATHER  5000000010000005000000010000100000001000000100...
# 5       PERSONALIZATION  5000000010000001000000005000000100000500000050...
# 6                FAMILY  5000000010000000100000000100000050000005000000...
# 7          PRODUCTIVITY  5000000001000000010000000010000000100000000010...
# 8        ART_AND_DESIGN  1000050000050000005000000010000050000500001000...
# 9             PARENTING  1000050000001000010000001000010000100000100005...
# 10               DATING  1000010005010010010010000000100000001000000010...
# ...

# %%
# what are top 5 installed apps in each popular category type ?

# %%
df_temp=df_copy.groupby(['Category','Type'])['Installs'].sum()

# %%
df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending=True).reset_index()
# Out:
#                Category  Type  \
# 0                EVENTS  Paid
# 1    LIBRARIES_AND_DEMO  Paid
# 2         COMMUNICATION  Free
# 3                SOCIAL  Free
# 4         VIDEO_PLAYERS  Free
# ..                  ...   ...
# 59  BOOKS_AND_REFERENCE  Paid
# 60   NEWS_AND_MAGAZINES  Paid
# 61            LIFESTYLE  Paid
# 62               FAMILY  Paid
# 63                  1.9     0
#
#                                              Installs
# 0                                                   1
# 1                                                 100
# 2   1000000000100000000010000000100000000010000000...
# 3   1000000000100000000050000000010000000100000000...
# 4   1000000000100000010000000100000010000001000000...
# ..                                                ...
# 59  5000100100005010001010101010151050010001050005...
# 60                                            5000500
# 61  5000500010000100005000100001000001000010001000...
# ...

# %%
df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending=True)
# Out:
# Category         Type
# EVENTS           Paid                                                   1+
# EDUCATION        Paid                         1,000+1,000+500,000+100,000+
# SOCIAL           Paid                                       1,000+5,000+0+
# MEDICAL          Free    1,000,000+1,000,000+1,000,000+1,000,000+1,000,...
# PERSONALIZATION  Paid    1,000,000+1,000,000+10,000+10,000+100,000+100+...
#                                                ...
# WEATHER          Free    50,000,000+1,000,000+50,000,000+10,000+10,000,...
# FAMILY           Free    50,000,000+10,000,000+100,000,000+1,000,000+5,...
# BEAUTY           Free    500,000+1,000,000+100,000+500,000+1,000,000+50...
# PRODUCTIVITY     Free    500,000,000+10,000,000+100,000,000+10,000,000+...
# 1.9              0                                                    Free
# Name: Installs, Length: 64, dtype: object

# %%
df_copy[df_copy.Category == "GAME"]
# Out:
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating  \
# 1653     100,000,000+  Free     0   Everyone 10+
# ...

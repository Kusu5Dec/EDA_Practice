# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# #Question 1:-

# %%
plt.hist(df.age,bins=30,edgecolor='blue')
plt.xlabel("age")
plt.ylabel("frequency")
plt.title("Age Distrubtion")
plt.show()

# %% [markdown]
# Question 2:-

# %%
df[['age','DEATH_EVENT']].isnull().sum()
age_death_rate=df.groupby('age')['DEATH_EVENT'].mean()
sns.set(style='whitegrid')

plt.figure(figsize=(12,6))
sns.lineplot(x=age_death_rate.index,y=age_death_rate.values)
plt.xlabel("age")
plt.ylabel("age_death_rate")
plt.title("death rate")
plt.show()

# %% [markdown]
# #Question:-3

# %%
df['sex'].isnull().sum()
sex_counts=df['sex'].value_counts()
total_len = len(df)
male_percentage=(sex_counts[1]/total_len)*100
female_percentage=(sex_counts[0]/total_len)*100
print(male_percentage)
print(female_percentage)
# Out:
# 64.88294314381271
# 35.11705685618729

# %% [markdown]
# #Question:-4

# %%
df[['platelets','age']].isnull().sum()
platelete_age=df.groupby('age')['platelets'].mean()


sns.set(style="whitegrid")
sns.lineplot(x=platelete_age.index,y=platelete_age.values)
plt.figure(figsize=(8,6))

plt.xlabel("age")
plt.ylabel("platelets count")
plt.title(" Difference between platelet count and age groups ")
plt.show()

# %% [markdown]
# #Question:-5

# %%
df[['serum_creatinine','serum_sodium']].isnull().sum()
correlation=df['serum_creatinine'].corr(df['serum_sodium'])
plt.figure(figsize=(12,8))
sns.scatterplot(x='serum_creatinine',y="serum_sodium",data=df)
plt.xlabel("creatinine")
plt.ylabel("Sodium")
plt.title("correlation between sodium and creatinine")
plt.show()

# %% [markdown]
# #Question:-6

# %%
prevalence_male_female=df.groupby('sex')['high_blood_pressure'].mean()
sex_labels={0:'female',1:'male'}
print(prevalence_male_female.values)
prevalence_male_female.index=prevalence_male_female.index.map(sex_labels)
print(prevalence_male_female)
plt.figure(figsize=(12,10))
sns.boxplot(x=prevalence_male_female.index,y=prevalence_male_female.values)
plt.xlabel("high blood pressure")
plt.ylabel('sex')
plt.title("prevalence_male_female")
plt.show()
# Out:
# [0.41904762 0.31443299]
# sex
# female    0.419048
# male      0.314433
# Name: high_blood_pressure, dtype: float64

# %% [markdown]
# #Question:-7

# %%
smoking_habits=df.groupby('smoking')['DEATH_EVENT'].mean()*100
print(smoking_habits)
smoking_labels={0:'no_smoking',1:'smoking'}
smoking_habits.index=smoking_habits.index.map(smoking_labels)
plt.figure(figsize=(8,6))
sns.boxplot(x=smoking_habits.index,y=smoking_habits.values)
plt.xlabel("smoking_habits")
plt.ylabel("sex")
plt.title("relationship b/w smkoer and non smoker")
plt.show()
# Out:
# smoking
# 0    32.512315
# 1    31.250000
# Name: DEATH_EVENT, dtype: float64

# %% [markdown]
# #

# %% [markdown]
# #Question:-8

# %%
bin = df['age'].values
# bin = df['age'].values
# bins = list(range(int(bin.min()),int(bin.max())))
bins = [0, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['0-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', '91-100']
df["age_g"]=pd.cut(df['age'],bins=bins,labels=labels,right=False)
df[['age_g',"DEATH_EVENT"]].isnull().sum()
temp  = df.groupby('age_g')['DEATH_EVENT'].mean()*100
plt.figure(figsize=(10,8))
sns.lineplot(x=temp.index,y=temp.values)
plt.xlabel("age_groups")
plt.ylabel("death_events")
plt.title("diff b/w death events and age groups")
plt.show()

# %% [markdown]
# #Question:-9

# %%
df[['ejection_fraction','diabetes']].isnull().sum()
diabetes_label={0:'no_diabetes',1:'diabetes'}
diabetes_ejection_fraction=df.groupby('diabetes')['ejection_fraction'].mean()
print(diabetes_ejection_fraction)
diabetes_ejection_fraction.index=diabetes_ejection_fraction.index.map(diabetes_label)

plt.figure(figsize=(8,6))
print(diabetes_ejection_fraction)
sns.lineplot(x=diabetes_ejection_fraction.index,y=diabetes_ejection_fraction.values)
plt.xlabel("diabete_status")
plt.ylabel("ejection_fraction")

plt.show()
# Out:
# diabetes
# 0    38.132184
# 1    38.016000
# Name: ejection_fraction, dtype: float64
# diabetes
# no_diabetes    38.132184
# diabetes       38.016000
# Name: ejection_fraction, dtype: float64

# %% [markdown]
# #Question:-10

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df[['serum_creatinine','DEATH_EVENT']].isnull().sum()
death_event_label={0:'dead',1:'alive'}
print(death_event_label)
serum_cretainie_death_event=df.groupby('DEATH_EVENT')['serum_creatinine'].mean()
serum_cretainie_death_event.index=serum_cretainie_death_event.index.map(death_event_label)
print(serum_cretainie_death_event)
plt.figure(figsize=(12,8))
sns.lineplot(x=serum_cretainie_death_event.index,y=serum_cretainie_death_event.values)
plt.xlabel("death_event")
plt.ylabel("serum_cretainie")
plt.show()
# Out:
# {0: 'dead', 1: 'alive'}
# DEATH_EVENT
# dead     1.184877
# alive    1.835833
# Name: serum_creatinine, dtype: float64

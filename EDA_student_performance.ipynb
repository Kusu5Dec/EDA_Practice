# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("student-mat.csv")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.school
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
# what are the count of students for each school

# %%
sns.countplot(x='school',data=df,palette='pastel')
# Out:
# <Axes: xlabel='school', ylabel='count'>

# %%
df.age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 390    20
# 391    17
# 392    21
# 393    18
# 394    19
# Name: age, Length: 395, dtype: int64

# %%
sns.histplot(df.age,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df.age,kde=True,color='salmon')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.address
# Out:
# 0      U
# 1      U
# 2      U
# 3      U
# 4      U
#       ..
# 390    U
# 391    U
# 392    R
# 393    R
# 394    U
# Name: address, Length: 395, dtype: object

# %%
df.address.unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(x='address',data=df,palette="dark")
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %%
df.reason
# Out:
# 0      course
# 1      course
# 2       other
# 3        home
# 4        home
#         ...
# 390    course
# 391    course
# 392    course
# 393    course
# 394    course
# Name: reason, Length: 395, dtype: object

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df['activities']
# Out:
# 0       no
# 1       no
# 2       no
# 3      yes
# 4       no
#       ...
# 390     no
# 391     no
# 392     no
# 393     no
# 394     no
# Name: activities, Length: 395, dtype: object

# %%
df['activities'].value_counts()
# Out:
# activities
# yes    201
# no     194
# Name: count, dtype: int64

# %%
df['Walc'].value_counts()
# Out:
# Walc
# 1    151
# 2     85
# 3     80
# 4     51
# 5     28
# Name: count, dtype: int64

# %%
df['Dalc'].value_counts()
# Out:
# Dalc
# 1    276
# 2     75
# 3     26
# 5      9
# 4      9
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.freetime
# Out:
# 0      3
# 1      3
# 2      3
# 3      2
# 4      3
#       ..
# 390    5
# 391    4
# 392    5
# 393    4
# 394    2
# Name: freetime, Length: 395, dtype: int64

# %%
sns.boxplot(df.freetime)
# Out:
# <Axes: >

# %%
df.studytime
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 390    2
# 391    1
# 392    1
# 393    1
# 394    1
# Name: studytime, Length: 395, dtype: int64

# %%
sns.histplot(df.studytime)
# Out:
# <Axes: xlabel='studytime', ylabel='Count'>

# %%
df['absences']
# Out:
# 0       6
# 1       4
# 2      10
# 3       2
# 4       4
#        ..
# 390    11
# 391     3
# 392     3
# 393     0
# 394     5
# Name: absences, Length: 395, dtype: int64

# %%
df['Pstatus']
# Out:
# 0      A
# 1      T
# 2      T
# 3      T
# 4      T
#       ..
# 390    A
# 391    T
# 392    T
# 393    T
# 394    T
# Name: Pstatus, Length: 395, dtype: object

# %%
df['Pstatus'].unique()   # A away, T  together
# Out:
# array(['A', 'T'], dtype=object)

# %%
sns.boxplot(data=df,x='Pstatus',y='absences')
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
df.sex
# Out:
# 0      F
# 1      F
# 2      F
# 3      F
# 4      F
#       ..
# 390    M
# 391    M
# 392    M
# 393    M
# 394    M
# Name: sex, Length: 395, dtype: object

# %%
df.sex.value_counts()
# Out:
# sex
# F    208
# M    187
# Name: count, dtype: int64

# %%
df.Fjob
# Out:
# 0       teacher
# 1         other
# 2         other
# 3      services
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393       other
# 394     at_home
# Name: Fjob, Length: 395, dtype: object

# %%
count=df.Fjob.value_counts()

# %%
count
# Out:
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: count, dtype: int64

# %%
count=df.Fjob.value_counts()
count.plot(kind='bar')
# Out:
# <Axes: xlabel='Fjob'>

# %%
counts=df.Mjob.value_counts()
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='Mjob'>

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Medu'}>,
#         <Axes: title={'center': 'Fedu'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'famrel'}>,
#         <Axes: title={'center': 'freetime'}>],
#        [<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'Dalc'}>,
#         <Axes: title={'center': 'Walc'}>,
#         <Axes: title={'center': 'health'}>],
#        [<Axes: title={'center': 'absences'}>,
#         <Axes: title={'center': 'G1'}>, <Axes: title={'center': 'G2'}>,
#         <Axes: title={'center': 'G3'}>]], dtype=object)

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.hist(bins=100,figsize=(30,40),color='blue')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Medu'}>,
#         <Axes: title={'center': 'Fedu'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'famrel'}>,
#         <Axes: title={'center': 'freetime'}>],
#        [<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'Dalc'}>,
#         <Axes: title={'center': 'Walc'}>,
#         <Axes: title={'center': 'health'}>],
#        [<Axes: title={'center': 'absences'}>,
#         <Axes: title={'center': 'G1'}>, <Axes: title={'center': 'G2'}>,
#         <Axes: title={'center': 'G3'}>]], dtype=object)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.G1.describe()
# Out:
# count    395.000000
# mean      10.908861
# std        3.319195
# min        3.000000
# 25%        8.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G1.value_counts()
# Out:
# G1
# 10    51
# 8     41
# 11    39
# 7     37
# 12    35
# 13    33
# 9     31
# 14    30
# 15    24
# 6     24
# 16    22
# 18     8
# 17     8
# 5      7
# 19     3
# 4      1
# 3      1
# Name: count, dtype: int64

# %%
sns.countplot(df,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
#do urban student score higher that rural student?

# %%
sns.kdeplot(df.loc[df['address']== 'U','G1'],label='Urban',shade=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12612\2596603364.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']== 'U','G1'],label='Urban',shade=True)
# <Axes: xlabel='G1', ylabel='Density'>

# %%
sns.kdeplot(df.loc[df['address']== 'R','G1'],label='Rural',shade=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12612\852610104.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']== 'R','G1'],label='Rural',shade=True)
# <Axes: xlabel='G1', ylabel='Density'>

# %%
sns.kdeplot(df.loc[df['address']== 'U','G1'],label='Urban',fill=True)
sns.kdeplot(df.loc[df['address']== 'R','G1'],label='Rural',fill=True)
import matplotlib.pyplot as plt

# Initialize a plot
plt.xlabel("Grade 1")

# Set the title
plt.title("comparison urban and rural area")

# Show the plot
plt.show()
